# %% [markdown]
# # Roller Coaster

# %% [markdown]
# #### Overview

# %% [markdown]
# This project is slightly different than others you have encountered thus far. Instead of a step-by-step tutorial, this project contains a series of open-ended requirements which describe the project you'll be building. There are many possible ways to correctly fulfill these requirements, and you should expect to use the internet, Codecademy, and other resources when you encounter a problem that you cannot easily solve.

# %% [markdown]
# #### Project Goals

# %% [markdown]
# You will work to create several data visualizations that will give you insight into the world of roller coasters.

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# In order to complete this project, you should have completed the first two lessons in the [Data Analysis with Pandas Course](https://www.codecademy.com/learn/data-processing-pandas) and the first two lessons in the [Data Visualization in Python course](https://www.codecademy.com/learn/data-visualization-python). This content is also covered in the [Data Scientist Career Path](https://www.codecademy.com/learn/paths/data-science/).

# %% [markdown]
# ## Project Requirements

# %% [markdown]
# 1. Roller coasters are thrilling amusement park rides designed to make you squeal and scream! They take you up high, drop you to the ground quickly, and sometimes even spin you upside down before returning to a stop. Today you will be taking control back from the roller coasters and visualizing data covering international roller coaster rankings and roller coaster statistics.
#
#    Roller coasters are often split into two main categories based on their construction material: **wood** or **steel**. Rankings for the best wood and steel roller coasters from the 2013 to 2018 [Golden Ticket Awards](http://goldenticketawards.com) are provded in `'Golden_Ticket_Award_Winners_Wood.csv'` and `'Golden_Ticket_Award_Winners_Steel.csv'`, respectively. Load each csv into a DataFrame and inspect it to gain familiarity with the data.

# %%
# 1 
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
from IPython.display import display

# %%
# load rankings data for wooden rollercoasters
wood = pd.read_csv('Golden_Ticket_Award_Winners_Wood.csv')
print('Dimension of wood: ', wood.shape) # (180, 8)
print('wood headers: ', wood.columns) # ['Rank', 'Name', 'Park', 'Location', 'Supplier', 'Year Built', 'Points','Year of Rank']
print(wood.dtypes)
print(wood.describe())
#print(wood.head())
display(wood)
# Out:
# Dimension of wood:  (180, 8)
# wood headers:  Index(['Rank', 'Name', 'Park', 'Location', 'Supplier', 'Year Built', 'Points',
#        'Year of Rank'],
#       dtype='object')
# Rank             int64
# Name            object
# Park            object
# Location        object
# Supplier        object
# Year Built       int64
# Points           int64
# Year of Rank     int64
# dtype: object
#              Rank   Year Built       Points  Year of Rank
# count  180.000000   180.000000   180.000000    180.000000
# mean    22.127778  1994.450000   392.388889   2016.500000
# std     15.217246    24.309061   381.816130      1.388299
# min      1.000000  1914.000000    66.000000   2013.000000
# 25%      8.000000  1994.000000   121.250000   2016.000000
# 50%     20.500000  2003.000000   213.500000   2017.000000
# 75%     35.250000  2009.000000   579.500000   2018.000000
# max     50.000000  2017.000000  1625.000000   2018.000000
# ...

# %% [markdown]
# __Wooden rollercoaster:__
# df has 180 rows and 8 columns.
# variables are:
# - Rank (int64): ordinal integer variable, rollercoaster popularity, ranges 1-50
# - Name (object): nominal variable, rollercoaster name
# - Park (object): nominal variable, theme park name
# - Location (object): nominal variable, theme park location
# - Supplier (object): nominal variable, rollercoaster supplier name
# - Year Built (int64): ordinal integer variable, year when rolloercoaster was built, ranges 1994-2017
# - Points (int64): quantitative integer variable, not sure but seems to be how rank was established, ranges 66-1625
# - Year of Rank (int64): ordinal integer variable, year was rank was established, ranges 2013-2018

# %%
# load rankings data for steel rollercoasters
steel = pd.read_csv('Golden_Ticket_Award_Winners_Steel.csv')
print('Dimension of steel: ', steel.shape) # (180, 8)
print('steel headers: ', steel.columns) # ['Rank', 'Name', 'Park', 'Location', 'Supplier', 'Year Built', 'Points','Year of Rank']
print(steel.dtypes)
print(steel.describe())
#print(steel.head())
display(steel)
# Out:
# Dimension of steel:  (180, 8)
# steel headers:  Index(['Rank', 'Name', 'Park', 'Location', 'Supplier', 'Year Built', 'Points',
#        'Year of Rank'],
#       dtype='object')
# Rank             int64
# Name            object
# Park            object
# Location        object
# Supplier        object
# Year Built       int64
# Points           int64
# Year of Rank     int64
# dtype: object
#              Rank   Year Built       Points  Year of Rank
# count  180.000000   180.000000   180.000000    180.000000
# mean    22.127778  2004.655556   325.433333   2016.500000
# std     15.186377     9.511723   279.650322      1.388299
# min      1.000000  1976.000000    59.000000   2013.000000
# 25%      8.000000  2000.000000   112.250000   2016.000000
# 50%     20.500000  2006.000000   246.000000   2017.000000
# 75%     35.250000  2012.000000   427.000000   2018.000000
# max     50.000000  2018.000000  1354.000000   2018.000000
# ...

# %% [markdown]
# __Steel rollercoaster:__
# df has 180 rows and 8 columns (same as wood).
# variables are the same as wood:
# - Rank (int64): ordinal integer variable, rollercoaster popularity, ranges 1-50
# - Name (object): nominal variable, rollercoaster name
# - Park (object): nominal variable, theme park name
# - Location (object): nominal variable, theme park location
# - Supplier (object): nominal variable, rollercoaster supplier name
# - Year Built (int64): ordinal integer variable, year when rolloercoaster was built, ranges 1976-20187
# - Points (int64): quantitative integer variable, not sure but seems to be how rank was established, ranges 59-1354
# - Year of Rank (int64): ordinal integer variable, year was rank was established, ranges 2013-2018

# %% [markdown]
# _NOTE:_
# Both datasets should be merged (concatenated) as they share the same columns and it would facilitate data analysis/visualisation. A new column 'Type' should be created first specifying 'wood' or 'steel' as to keep track of original datasets.

# %%
# add rollercoaster type
wood['Type'] = 'wood'
#display(wood)
steel['Type'] = 'steel'
#display(steel)
# concatenate both datasets
rollercoaster = pd.concat([wood, steel], axis=0)
#print(rollercoaster.head())
display(rollercoaster)
# Out:
#      Rank                Name                       Park             Location  \
# 0       1        Boulder Dash             Lake Compounce       Bristol, Conn.
# 1       2             El Toro  Six Flags Great Adventure        Jackson, N.J.
# 2       3             Phoenix  Knoebels Amusement Resort        Elysburg, Pa.
# 3       4          The Voyage              Holiday World    Santa Claus, Ind.
# 4       5         Thunderhead                  Dollywood  Pigeon Forge, Tenn.
# ..    ...                 ...                        ...                  ...
# 175    46  Expedition Everest    Disney’s Animal Kingdom        Orlando, Fla.
# 176    47        Storm Chaser           Kentucky Kingdom      Louisville, Ky.
# 177    48         Raging Bull    Six Flags Great America         Gurnee, Ill.
# 178    49         Thunderbird              Holiday World    Santa Claus, Ind.
# 179    50             Whizzer    Six Flags Great America         Gurnee, Ill.
#
# ...

# %% [markdown]
# 2. Write a function that will plot the ranking of a given roller coaster over time as a line. Your function should take a roller coaster's name and a ranking DataFrame as arguments. Make sure to include informative labels that describe your visualization.
#
#    Call your function with `"El Toro"` as the roller coaster name and the wood ranking DataFrame. What issue do you notice? Update your function with an additional argument to alleviate the problem, and retest your function.

# %%
# display el toro details
#print(rollercoaster[rollercoaster['Name'] == 'El Toro']) # note: El Toro name is common to 2 different parks
display(rollercoaster[rollercoaster['Name'] == 'El Toro']) # note: El Toro name is common to 2 different parks
# Out:
#      Rank     Name                       Park             Location  \
# 1       2  El Toro  Six Flags Great Adventure        Jackson, N.J.
# 11      2  El Toro  Six Flags Great Adventure        Jackson, N.J.
# 21      2  El Toro  Six Flags Great Adventure        Jackson, N.J.
# 32      3  El Toro  Six Flags Great Adventure        Jackson, N.J.
# 55     25  El Toro        Freitzeitpark Plohn  Legendfeld, Germany
# 80      1  El Toro  Six Flags Great Adventure        Jackson, N.J.
# 120    41  El Toro        Freitzeitpark Plohn  Legendfeld, Germany
# 131     2  El Toro  Six Flags Great Adventure        Jackson, N.J.
#
#                 Supplier  Year Built  Points  Year of Rank  Type
# 1                Intamin        2006    1302          2013  wood
# 11               Intamin        2006    1291          2014  wood
# 21               Intamin        2006    1464          2015  wood
# 32               Intamin        2006    1121          2016  wood
# ...

# %%
# display boulder dash hurricane details
#print(rollercoaster[rollercoaster['Name'] == 'Boulder Dash']) # note: Boulder Dash name is unique to 1 park
display(rollercoaster[rollercoaster['Name'] == 'Boulder Dash']) # note: Boulder Dash name is unique to 1 park
# Out:
#      Rank          Name            Park        Location         Supplier  \
# 0       1  Boulder Dash  Lake Compounce  Bristol, Conn.              CCI
# 10      1  Boulder Dash  Lake Compounce  Bristol, Conn.              CCI
# 20      1  Boulder Dash  Lake Compounce  Bristol, Conn.              CCI
# 30      1  Boulder Dash  Lake Compounce  Bristol, Conn.  Custom Coasters
# 82      3  Boulder Dash  Lake Compounce  Bristol, Conn.  Custom Coasters
# 133     4  Boulder Dash  Lake Compounce  Bristol, Conn.  Custom Coasters
#
#      Year Built  Points  Year of Rank  Type
# 0          2000    1333          2013  wood
# 10         2000    1480          2014  wood
# 20         2000    1625          2015  wood
# 30         2000    1216          2016  wood
# 82         2000    1171          2017  wood
# 133        2000     982          2018  wood

# %%
# 2
# Create a function to plot rankings over time for 1 roller coaster
def time_line(df, rollercoaster_name):
    # isolating rollercoaster name
    rollercoaster_data = df[df['Name'] == rollercoaster_name]  # Filter the DataFrame based on roller coaster name
    # creating lineplot
    sns.lineplot(x='Year of Rank', y='Rank', data=rollercoaster_data, hue='Park', marker='o', palette='deep')
    plt.title('Rank of rollercoaster ' + rollercoaster_name + ' in multiple parks')
    plt.xlabel('Year of Rank')
    plt.ylabel('Rank')
    plt.legend(title='Park', loc='center left', bbox_to_anchor=(1, 0.5))
    plt.gca().invert_yaxis()  # Invert the y-axis so that top rank 1 is at the top
    plt.show()
    plt.clf()
    
# Create a plot of El Toro ranking over time
time_line(rollercoaster, 'El Toro')

# %% [markdown]
# 3. Write a function that will plot the ranking of two given roller coasters over time as lines. Your function should take both roller coasters' names and a ranking DataFrame as arguments. Make sure to include informative labels that describe your visualization.
#
#    Call your function with `"El Toro"` as one roller coaster name, `"Boulder Dash"` as the other roller coaster name, and the wood ranking DataFrame. What issue do you notice? Update your function with two additional arguments to alleviate the problem, and retest your function.

# %%
# 3
# Create a function to plot rankings over time for 2 roller coasters
def rollercoaster_ranking(df, rollercoaster_park_data, *rollercoaster_names):
    # isolate rollercoaster name and park name
    for name, park in rollercoaster_park_data:
        rollercoaster_data = df[(df['Name'] == name) & (df['Park'] == park)]  # Filter the DataFrame based on roller coaster name and park
        # create line plot
        sns.lineplot(x='Year of Rank', y='Rank', data=rollercoaster_data, marker='o', label=f'{name} ({park})')
    # add details to line plot
    plt.title('Rank of rollercoasters')
    plt.xlabel('Year of Rank')
    plt.ylabel('Rank')
    plt.legend(title='Rollercoaster (Park)', loc='center left', bbox_to_anchor=(1, 0.5))
    plt.gca().invert_yaxis()  # Invert the y-axis so that top rank 1 is at the top
    plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))  # Set the y-axis tick locator to display only integers
    plt.show()
    plt.clf()

#  Create a plot of El Toro and Boulder Dash ranking over time at specific locations
rollercoaster_park_data = [('El Toro', 'Six Flags Great Adventure'), ('Boulder Dash', 'Lake Compounce')]
rollercoaster_ranking(rollercoaster, rollercoaster_park_data, 'El Toro', 'Boulder Dash')

# %% [markdown]
# 4. Write a function that will plot the ranking of the top `n` ranked roller coasters over time as lines. Your function should take a number `n` and a ranking DataFrame as arguments. Make sure to include informative labels that describe your visualization.
#
#    For example, if `n == 5`, your function should plot a line for each roller coaster that has a rank of `5` or lower.
#
#    Call your function with a value of `n` and either the wood ranking or steel ranking DataFrame.

# %%
# 4
# Create a function to plot top n ranking rollercoasters over time
def top_ranking(df,n):
    # isolate top ranking roller coaster
    top_n = df[(df.Rank <= n)]
    # creating lineplot for top_n rollercoasters
    sns.lineplot(x='Year of Rank', y='Rank', data=top_n, hue='Name', marker='o', palette='deep')
    plt.title('Best ranking rollercoasters')
    plt.xlabel('Year of Rank')
    plt.ylabel('Rank')
    plt.gca().invert_yaxis()  # Invert the y-axis so that top rank 1 is at the top
    plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))  # Set the y-axis tick locator to display only integers
    plt.legend(title='Rank', loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()
    plt.clf()

# Create a plot of top 3 rankings over time
top_ranking(rollercoaster, 3)

# %% [markdown]
# 5. Now that you've visualized rankings over time, let's dive into the actual statistics of roller coasters themselves. [Captain Coaster](https://captaincoaster.com/en/) is a popular site for recording roller coaster information. Data on all roller coasters documented on Captain Coaster has been accessed through its API and stored in `roller_coasters.csv`. Load the data from the csv into a DataFrame and inspect it to gain familiarity with the data.

# %%
# 5
# load roller coaster data
roller_data = pd.read_csv('roller_coasters.csv')
print('Dimension of data: ', roller_data.shape) # (2802, 10)
print('data headers: ', roller_data.columns) # ['name','material_type','seating_type','speed','height','length','num_inversions','manufacturer','park','status']
print(roller_data.dtypes)
print(roller_data.describe())
#print(roller_data.head())
display(roller_data)
# Out:
# Dimension of data:  (2802, 10)
# data headers:  Index(['name', 'material_type', 'seating_type', 'speed', 'height', 'length',
#        'num_inversions', 'manufacturer', 'park', 'status'],
#       dtype='object')
# name               object
# material_type      object
# seating_type       object
# speed             float64
# height            float64
# length            float64
# num_inversions    float64
# manufacturer       object
# park               object
# status             object
# dtype: object
#              speed       height       length  num_inversions
# count  1478.000000  1667.000000  1675.000000     2405.000000
# mean     70.102842    26.725855   606.147463        0.809563
# std      28.338394    35.010166   393.840496        1.652254
# min       0.000000     0.000000    -1.000000        0.000000
# 25%      47.000000    13.000000   335.000000        0.000000
# 50%      72.000000    23.000000   500.000000        0.000000
# ...

# %% [markdown]
# __Data rollercoaster:__
# df has 2802 rows and 10 columns.
# variables are:
# - name (object): nominal variable, rollercoaster name
# - material_type (object): nominal variable, construction material (Steel or Wooden)
# - seating_type: (object): nominal variable, seating arrangement (Sit, Down, Suspended, Spinning, ...)
# - speed (float64): quantitative variable (float), rollercoaster speed, ranges 0-240(m/h)
# - height (float64): quantitative variable (float), rollercoaster height, ranges 0-902(m)
# - length (float64): quantitative variable (float), rollercoaster length, ranges -1-2920 (m)
# - num_inversions (float64): quantitative variable (float), number of loops, ranges 0-14
# - manufacturer (object): nominal variable, rollercoaster manufacturer name
# - park (object): nominal variable, theme park name
# - status (object): nominal variable, rollercoaster operating status (operating, rummored, announced, ...)

# %% [markdown]
# 6. Write a function that plots a histogram of any numeric column of the roller coaster DataFrame. Your function should take a DataFrame and a column name for which a histogram should be constructed as arguments. Make sure to include informative labels that describe your visualization.
#
#    Call your function with the roller coaster DataFrame and one of the column names.

# %%
# 6
# Create a function to plot histogram of column values
def histogram(df, col, i, j):
    # Use the variable col to access the column in the DataFrame
    plt.hist(df[col], edgecolor='white', bins=i, color=j)
    plt.title('Distribution of ' + col)  # Use the variable col directly
    plt.xlabel('Bins')
    plt.ylabel('Counts')
    plt.show()
    plt.clf()

# Create histogram of roller coaster speed
histogram(roller_data, 'speed', 50, 'orange')
# Create histogram of roller coaster length
histogram(roller_data, 'length', 50, 'green')
# Create histogram of roller coaster number of inversions
histogram(roller_data, 'num_inversions', 5, 'purple')

# %%
# display height
display(roller_data.height) # NaNs present, that's why I can't draw a box plot
 
# Remove NaN values from the height
height_no_na = roller_data['height'].dropna()

# Checking height distribution
plt.figure(figsize=(1,5))
plt.boxplot(height_no_na, widths=0.8)
plt.show() # lots of outliers
plt.clf()

# display quartiles and max
print(height_no_na.describe()) # 75% less than 35m.
print('Maximum rollercoaster height: ', height_no_na.max()) # 902.0  ! is this real or a typo?

# limiting the height
heights = roller_data[roller_data['height'] <= 100]

# Create a function to plot histogram of height values by removing outliers >100m
def histogram_height(df, col, i, j):
    # Use the variable col to access the column in the DataFrame
    plt.hist(df[col], edgecolor='white', bins=i, color=j)
    plt.title('Distribution of ' + col)  # Use the variable col directly
    plt.xlabel('Bins')
    plt.ylabel('Counts')
    plt.show()
    plt.clf()

# Create a histogram of roller coaster height
histogram_height(heights, 'height', 10, 'pink')
# Out:
# 0       37.0
# 1       25.0
# 2        8.0
# 3       35.0
# 4       17.0
#         ...
# 2797     NaN
# 2798     NaN
# 2799    30.0
# 2800     NaN
# 2801    11.0
# Name: height, Length: 2802, dtype: float64
# count    1667.000000
# mean       26.725855
# std        35.010166
# min         0.000000
# 25%        13.000000
# 50%        23.000000
# 75%        35.000000
# max       902.000000
# Name: height, dtype: float64
# Maximum rollercoaster height:  902.0

# %% [markdown]
# 7. Write a function that creates a bar chart showing the number of inversions for each roller coaster at an amusement park. Your function should take the roller coaster DataFrame and an amusement park name as arguments. Make sure to include informative labels that describe your visualization.
#
#    Call your function with the roller coaster DataFrame and amusement park name.

# %%
# 7
# Create a function to plot inversions by coaster at park
# display loops
#display(roller_data.num_inversions) # no NaNs
# group coasters by number of loops 
display(roller_data.num_inversions[data.num_inversions > 0].groupby(data.num_inversions).count()) # lots of coasters with loops. need to subset
# display coasters with => 8 loops
display(roller_data.num_inversions[data.num_inversions >= 8].groupby(data.num_inversions).count()) # 13 coasters 

# display quartiles and max
print(roller_data.num_inversions.describe()) # only the 4th quarter features loops.
print('Maximum rollercoaster loops: ', roller_data.num_inversions.max()) # 14

# Create a function to plot inversions by coaster at park
def inversion(df, n):
    # limiting the number of loops
    loops = df[df['num_inversions'] >= n]
    # creating barplot of rollercoasters with n loops
    plt.bar(data=loops, x='name' , height='num_inversions', color='turquoise')
    plt.title('Rollercoasters featuring more than 7 loops')
    plt.xlabel('Rollercoaster name')
    plt.xticks(rotation=90) # rotate x axis labels 90
    plt.ylabel('Number of loops')
    plt.show()
    plt.clf()

# Create barplot of inversions by roller coasters    
inversion(roller_data, 8)
# Out:
# num_inversions
# 1.0     135
# 2.0     126
# 3.0     150
# 4.0      87
# 5.0      80
# 6.0      21
# 7.0      16
# 8.0       5
# 9.0       1
# 10.0      5
# 11.0      1
# 14.0      1
# Name: num_inversions, dtype: int64
# num_inversions
# 8.0     5
# 9.0     1
# 10.0    5
# 11.0    1
# 14.0    1
# Name: num_inversions, dtype: int64
# count    2405.000000
# mean        0.809563
# std         1.652254
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max        14.000000
# Name: num_inversions, dtype: float64
# Maximum rollercoaster loops:  14.0

# %% [markdown]
# 8. Write a function that creates a pie chart that compares the number of operating roller coasters (`'status.operating'`) to the number of closed roller coasters (`'status.closed.definitely'`). Your function should take the roller coaster DataFrame as an argument. Make sure to include informative labels that describe your visualization.
#
#    Call your function with the roller coaster DataFrame.

# %%
# 8
# Create a function to plot a pie chart of status.operating
# status type
print(roller_data.status.unique()) 
# ['status.operating','status.relocated','status.closed.definitely','status.retracked','status.closed.temporarily','status.unknown', 'status.construction','status.announced','status.rumored']
def pie(df):
    # isolating operating status
    operating = df[df.status == 'status.operating']
    operating_len = len(operating)
    # cisolating closed definitely status
    closed_definitely = df[df.status == 'status.closed.definitely']
    closed_definitely_len = len(closed_definitely)
    # proportions of both
    prop = [operating_len,closed_definitely_len] 
    # plotting pie
    plt.pie(prop, labels=['operating','closed definitely'], startangle=0, autopct='%1.1f%%')
    plt.axis('equal')
    plt.title('Proportion of Rollercoaster Status')
    plt.show()
    plt.clf()

# Create pie chart of roller coasters
pie(roller_data)
# Out:
# ['status.operating' 'status.relocated' 'status.closed.definitely'
#  'status.retracked' 'status.closed.temporarily' 'status.unknown'
#  'status.construction' 'status.announced' 'status.rumored']

# %% [markdown]
# 9. `.scatter()` is another useful function in matplotlib that you might not have seen before. `.scatter()` produces a scatter plot, which is similar to `.plot()` in that it plots points on a figure. `.scatter()`, however, does not connect the points with a line. This allows you to analyze the relationship between two variables. Find [`.scatter()`'s documentation here](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html).
#
#    Write a function that creates a scatter plot of two numeric columns of the roller coaster DataFrame. Your function should take the roller coaster DataFrame and two-column names as arguments. Make sure to include informative labels that describe your visualization.
#
#    Call your function with the roller coaster DataFrame and two-column names.

# %%
# 9
# Create a function to plot scatter of any two columns
def scatter(df, var1, var2, i):
    # create scatterplot using actual values from the DataFrame
    plt.scatter(x=df[var1], y=df[var2], s=3, color=i)  # Extract values from the DataFrame directly
    plt.title('Relationship between ' + var1 + ' and ' + var2)
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.show()

# Plot speed vs length
scatter(roller_data, 'speed', 'length', 'orange')
# Plot speed vs loops
scatter(roller_data, 'speed', 'num_inversions', 'green')

# limit height to 200m
heights2 = roller_data[roller_data['height'] <= 200]

# Create a function to plot scatter of speed vs height
def scatter_height(df, var1, var2, i):
    # create scatterplot using actual values from the DataFrame
    plt.scatter(x=df[var1], y=df[var2], s=3, color=i)  # Extract values from the DataFrame directly
    plt.title('Relationship between ' + var1 + ' and ' + var2)
    plt.xlabel(var1)
    plt.ylabel(var2)
    plt.show()
# Create a scatter plot of roller coaster height by speed
scatter_height(heights2, 'height', 'speed', 'blue')
# Create a scatter plot of roller coaster height by length
scatter_height(heights2, 'height', 'length', 'maroon')

# %% [markdown]
# 10. Part of the fun of data analysis and visualization is digging into the data you have and answering questions that come to your mind.
#
#     Some questions you might want to answer with the datasets provided include:
#     - What roller coaster seating type is most popular? And do different seating types result in higher/faster/longer roller coasters?
#     - Do roller coaster manufactures have any specialties (do they focus on speed, height, seating type, or inversions)?
#     - Do amusement parks have any specialties?
#
#     What visualizations can you create that answer these questions, and any others that come to you? Share the questions you ask and the accompanying visualizations you create on the Codecademy forums.

# %%
# Most popular seating type
# seating types
display(roller_data.seating_type.unique()) # NaNs present
#['Sit Down','Suspended','Inverted','Spinning','Water Coaster','Floorless','Bobsleigh','Stand Up','Flying','4th Dimension','Pipeline','Motorbike','Wing','Alpine','na']
# dropping NAs
seating_no_na = roller_data[roller_data['seating_type'] != 'na']
#display(seating_no_na)
display(seating_no_na.seating_type.unique()) # no NAs

# Create a function to plot seating type
def seating(df, var):
    # count occurrences of each seating type
    counts = df[var].value_counts()
    # plot
    plt.bar(x=counts.index, height=counts, color='green')
    plt.title('Popularity of ' + var)
    plt.xlabel(var)
    plt.xticks(rotation=90) # rotate x axis labels 90
    plt.ylabel('Counts')
    plt.show()
            
# plotting data
seating(seating_no_na, 'seating_type') # Sit Down are the most popular options
# Out:
# array(['Sit Down', 'Suspended', 'Inverted', 'Spinning', 'Water Coaster',
#        'Floorless', 'Bobsleigh', 'Stand Up', 'Flying', '4th Dimension',
#        'Pipeline', 'Motorbike', 'Wing', 'Alpine', 'na'], dtype=object)
# array(['Sit Down', 'Suspended', 'Inverted', 'Spinning', 'Water Coaster',
#        'Floorless', 'Bobsleigh', 'Stand Up', 'Flying', '4th Dimension',
#        'Pipeline', 'Motorbike', 'Wing', 'Alpine'], dtype=object)

# %%
# Manufacturers specialties
# unique manufacturers
#display(roller_data.manufacturer.unique()) # ['Vekoma', 'Zamperla', 'William J. Cobb', 'Soquet', 'Pinfari', etc...

#function plots bar graph for desired 'builder' and shows averages for
#each of height, speed, length, and number inversions
#function accepts a dataframe of coaster data and a string with manufacturer name
def manufacturer(df, builder):
    builder_data = df[df.manufacturer == builder]
    avg_height = builder_data.height.mean()
    avg_speed = builder_data.speed.mean()
    avg_length = builder_data.length.mean()
    avg_inversions = builder_data.num_inversions.mean()
    #Only wanted to show '<1' for data as it is somewhat meaningless to 
    #have .24 inversion, for example
    if avg_inversions < 1:
        avg_inversion_text = '< 1'
    else:
        avg_inversion_text = str(round(avg_inversions))
    ax = plt.subplot()
    plt.bar(range(4), [avg_height, avg_speed, avg_length, avg_inversions])
    #Plotting calculated averages on each bar
    ax.text(0, avg_height + 5, str(round(avg_height,2)), horizontalalignment='center', fontsize=12)
    ax.text(1, avg_speed + 5, str(round(avg_speed,2)), horizontalalignment='center', fontsize=12)
    ax.text(2, avg_length + 5, str(round(avg_length,2)), horizontalalignment='center', fontsize=12)
    ax.text(3, avg_inversions + 5, avg_inversion_text, horizontalalignment='center', fontsize=12)
    ax.set_xticks(range(4))
    ax.set_xticklabels(['Avg Height(m)', 'Avg Speed (kmh)', 'Avg Length (km)', 'Avg # of Inversions'], rotation=90)
    plt.title('Averages on ' + str(len(builder_data)) + ' Coasters for Manufacturer: ' + builder)
    plt.show()
    plt.clf()

# plot
manufacturer(roller_data, 'Vekoma')

# %%
#function will plot a line graph of the parks with the 20 highest, longest,
#or fastest coaster... function accepts 'height','length','speed' 
#and 'num_inversions' for col_name
def top20(df, col_name):
    #find heightest coaster for each park, ignore nans and 0s
    park_data = df[df[col_name] != 0].groupby('park')[col_name].max().dropna().reset_index()
    #Too much data! Plot only top 20 parks with highest coasters
    top_20_park_data = park_data[col_name].nlargest(n=20).reset_index()
    #Now we have a df with height data, also need a matching list of park names
    #for the x labels
    top_20_park_names = []
    for row in range(len(top_20_park_data)):
        top_20_park_names.append(park_data.iloc[int(top_20_park_data['index'][row])].park)
    ax = plt.subplot()
    #print(list(zip(top_20_park_names, top_20_park_data[col_name])))
    plt.plot(range(len(top_20_park_data)), top_20_park_data[col_name])
    ax.set_xticks(range(len(top_20_park_data)))
    ax.set_xticklabels(top_20_park_names, rotation = 90)
    plt.ylabel(col_name)
    #Pick the appropriate title based on col_name
    if col_name == 'speed':
        plt.title('Top 20 Parks with Fastest Coasters')
    elif col_name == 'height':
        plt.title('Top 20 Parks with Heighest Coasters')
    elif col_name == 'length':
        plt.title('Top 20 Parks with Longest Coasters')
    else: #num_inversions
        plt.title('Top 20 Parks with Coasters having most Inversions')
    plt.show()
    plt.clf()
    
# plot data
top20(roller_data, 'speed')
top20(roller_data, 'height')
top20(roller_data, 'length')

# %% [markdown]
# ## Solution

# %% [markdown]
# Great work! Visit [our forums](https://discuss.codecademy.com/t/roller-coaster-challenge-project-python-pandas/462378) or the file **Roller Coaster_Solution.ipynb** to compare your project to our sample solution code. You can also learn how to host your own solution on GitHub so you can share it with other learners! Your solution might look different from ours, and that's okay! There are multiple ways to solve these projects, and you'll learn more by seeing others' code.
